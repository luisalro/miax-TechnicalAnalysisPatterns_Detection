# %% [markdown]
# ## Práctica Machine Learning
# #### Clasificación de patrones técnicos

# %% [markdown]
# Este cuaderno incluye un script para la descarga de datos de EUROSTOXX de la API de BME y su posterior guardado en un csv.

# %% [markdown]
# ### Descarga de datos de EUROSTOXX de la API de BME

# %% [markdown]
# #### Importamos librerias

# %%
from datetime import date,datetime,timedelta
import pandas as pd
import numpy as np
import requests, json

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Descarga de datos

# %% [markdown]
# La comunicación via API se realiza a través de la siguiente dirección web

# %%
url_base = 'https://miax-gateway-jog4ew3z3q-ew.a.run.app'
headers = {'Content-Type': 'application/json'}

# %% [markdown]
# Es necesario indicar en la petición el identificador
# de la competición y la clave personal

# %%
competi = 'mia_4'
user_key = 'AIzaSyBIAVe1BIJaxb-LVyMYMmhtoPPdJZSfRqI'

# %% [markdown]
# #### Serie del Indice ####
# Para acceder al precio del índice se utiliza
# el ticker 'benchmark'.

# %%
url = f'{url_base}/data/time_series'

# %%
params = {'market': 'EUROSTOXX',
          'key': 'AIzaSyBIAVe1BIJaxb-LVyMYMmhtoPPdJZSfRqI',
          'ticker': 'benchmark',
          'close': False}
response = requests.get(url, params)
tk_data = response.json()

# %%
benchmark_eurostoxx = pd.read_json(tk_data, typ='frame')
benchmark_eurostoxx.head()
# Out:
#                open     high      low    close  vol
# 2010-01-04  4713.30  4781.32  4713.30  4781.32    0
# 2010-01-05  4779.49  4793.68  4763.38  4772.71    0
# 2010-01-06  4770.38  4779.79  4748.45  4768.44    0
# 2010-01-07  4753.34  4775.15  4721.13  4764.75    0
# 2010-01-08  4773.67  4792.07  4743.18  4781.40    0

# %% [markdown]
# ### Guardado en CSV

# %% [markdown]
# Guardamos el fichero en CSV para su posterior procesamiento

# %%
benchmark_eurostoxx.to_csv('benchmark_eurostoxx.csv')

# %% [markdown]
# #### Cargamos la serie del EUROSTOXX para comprobar que se ha guardado correctamente

# %%
benchmark_eurostoxx = pd.read_csv('benchmark_eurostoxx.csv',parse_dates = True) 
benchmark_eurostoxx
# Out:
#       Unnamed: 0     open     high      low    close  vol
# 0     2010-01-04  4713.30  4781.32  4713.30  4781.32    0
# 1     2010-01-05  4779.49  4793.68  4763.38  4772.71    0
# 2     2010-01-06  4770.38  4779.79  4748.45  4768.44    0
# 3     2010-01-07  4753.34  4775.15  4721.13  4764.75    0
# 4     2010-01-08  4773.67  4792.07  4743.18  4781.40    0
# ...          ...      ...      ...      ...      ...  ...
# 2699  2020-07-13  7145.22  7234.62  7136.02  7227.59    0
# 2700  2020-07-14  7187.55  7187.55  7073.85  7168.81    0
# 2701  2020-07-15  7191.35  7337.84  7191.35  7291.44    0
# 2702  2020-07-16  7276.00  7287.93  7211.04  7263.68    0
# 2703  2020-07-17  7274.81  7284.98  7239.15  7264.23    0
#
# [2704 rows x 6 columns]

# %% [markdown]
# ___
