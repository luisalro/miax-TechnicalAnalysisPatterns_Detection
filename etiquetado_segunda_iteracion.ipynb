# %% [markdown]
# ## Práctica Machine Learning
# #### Clasificación de patrones técnicos

# %% [markdown]
# Este cuaderno incluye un script para el etiquetado de gráficas de velas, que son
# elegidas de forma aleatoria a partir de los datos diarios del IBEX35.
# Para más detalle consultar el enunciado de la práctica

# %% [markdown]
# ### Fase de etiquetado de la segunda iteración

# %% [markdown]
# Esta fase consistirá en etiquetar las ventanas temporales del IBEX como ejemplos de doble suelo,doble techo y sin patrón.

# %% [markdown]
# #### Importamos librerias

# %%
import numpy as np
import pandas as pd

import pickle

import matplotlib.pyplot as plt

# %% [markdown]
# #### Cargamos la serie del IBEX

# %%
with open('benchmark_data.pkl', 'rb') as handle:
    bm = pickle.load(handle)

# %%
ibex = bm['ibex']

# %%
ibex.head()
# Out:
#               close     high      low     open          vol
# 2000-01-03  11610.0  11881.8  11574.4  11846.6   60107000.0
# 2000-01-04  11206.6  11530.0  11159.8  11499.5   62539000.0
# 2000-01-05  10863.1  11068.1  10824.9  11206.6   68153000.0
# 2000-01-07  11102.4  11137.9  10882.7  10963.4  144207000.0
# 2000-01-10  11173.3  11364.3  11120.6  11363.8  133817000.0

# %% [markdown]
# #### Instalación e importación de librería mpl_finance
# Para realizar los gráficos de velas, utilizaremos la librería mpl_finance.

# %%
from mpl_finance import candlestick2_ohlc

# %% [markdown]
# ___

# %% [markdown]
# #### Bucle de Etiquetado
#
# El siguiente código es un bucle que:
# 1. Elige una posición aleatoria de la serie del IBEX para crear una ventana de 30 días
# 2. Dibuja el gráfico de velas.
# 3. Pide al usuario que introduzca un número para etiquetar la gráfica.
#
# Primero hay que elegir el tamaño de la ventana y el número de ejemplos que se quieren generar.
# Se tiene la opción de descartar algún ejemplo si no se quiere incluir (ej. posiblemente ambiguo)

# %%
window = 30
n = 400

# %%
etiquetas = np.zeros(n)
idfechas = np.zeros(n)
for i in range(n):
    idx = np.random.randint(0, ibex.shape[0] - window)
    idfechas[i] = idx
    windata = ibex.iloc[idx:idx+window]
    fig, ax = plt.subplots(figsize=(6,4))
    _ = candlestick2_ohlc(ax, windata.open, windata.high,
                         windata.low, windata.close,
                         colorup='g', colordown='r', width=0.66, alpha=0.8)
    plt.show()
    print(f'Ejemplo {i+1} de {n}')
    print("Etiquete la siguiete grafica como:")
    print(" [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo")
    opcion_usuario = input()
    if opcion_usuario >= '0' and opcion_usuario <= '3':
        etiquetas[i] = opcion_usuario   
    else:
        print('Error en la opción introducida. Ejemplo descartado')
        etiquetas[i] = 3
# Out:
# Ejemplo 1 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 2 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 3 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 4 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 5 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 6 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 7 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 8 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 9 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 10 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 11 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 12 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 13 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 14 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 15 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 16 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 17 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 18 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 19 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 20 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 21 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 22 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 23 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 24 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 25 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 26 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 27 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 28 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 29 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 30 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 31 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 32 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 33 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 34 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 35 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 36 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 37 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 38 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 39 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 40 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 41 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 42 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 43 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 44 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 45 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 46 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 47 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 48 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 49 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 50 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 51 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 52 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 53 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 54 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 55 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 56 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 57 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 58 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 59 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 60 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 61 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 62 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 63 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 64 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 65 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 66 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 67 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 68 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 69 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 70 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 71 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 72 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 73 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 74 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 75 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 76 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 77 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 78 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 79 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 80 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 81 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 82 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 83 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 84 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 85 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 86 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 87 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 88 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 89 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 90 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 91 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 92 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 93 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 94 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 95 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 96 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 97 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 98 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 99 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 100 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 101 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 102 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 103 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 104 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 105 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 106 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 107 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 108 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 109 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 110 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 111 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 112 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 113 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 114 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 115 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 116 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 117 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 118 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 119 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 120 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 121 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 122 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 123 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 124 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 125 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 126 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 127 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 128 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 129 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 130 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 131 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 132 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 133 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 134 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 135 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 136 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 137 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 138 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 139 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 140 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 141 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 142 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 143 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 144 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 145 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 146 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 147 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 148 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 149 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 150 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 151 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 152 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 153 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 154 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 155 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 156 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 157 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 158 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 159 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 160 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 161 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 162 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 163 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 164 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 165 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 166 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 167 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 168 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 169 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 170 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 171 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 172 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 173 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 174 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 175 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 176 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 177 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 178 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 179 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 180 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 181 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 182 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 183 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 184 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 185 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 186 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 187 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 188 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 189 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 190 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 191 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 192 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 193 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 194 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 195 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 196 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 197 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 198 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 199 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 200 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 201 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 202 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 203 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 204 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 205 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 206 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 207 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 208 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 209 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 210 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 211 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 212 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 213 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 214 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 215 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 216 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 217 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 218 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 219 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 220 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 221 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 222 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 223 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 224 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 225 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 226 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 227 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 228 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 229 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 230 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 231 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 232 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 233 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 234 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 235 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 236 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 237 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 238 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 239 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 240 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 241 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 242 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 243 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 244 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 245 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 246 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 247 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 248 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 249 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 250 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 251 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 252 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 253 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 254 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 255 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 256 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 257 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 258 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 259 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 260 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 261 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 262 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 263 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 264 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 265 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 266 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 267 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 268 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 269 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 270 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 271 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 272 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 273 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 274 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 275 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 276 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 277 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 278 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 279 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 280 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 281 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 282 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 283 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 284 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 285 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 286 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 287 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 288 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 289 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 290 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 291 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 292 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 293 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 294 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 295 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 296 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 297 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 298 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 299 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 300 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 301 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 302 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 303 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 304 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 305 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 306 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 307 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 308 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 309 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 310 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 311 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 312 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 313 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 314 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 315 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 316 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 317 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 318 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 319 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 320 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 321 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 322 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 323 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 324 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 325 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 326 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 327 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 328 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 329 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 330 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 331 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 332 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 333 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 334 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 335 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 336 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 337 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 338 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 339 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 340 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 341 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 342 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 343 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 344 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 345 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 346 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 3
# Ejemplo 347 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 348 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 349 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 350 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 351 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 352 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 353 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 354 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 355 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 356 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 357 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 358 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 359 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 360 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 361 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 362 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 363 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 364 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 365 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 366 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 367 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 368 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 369 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 370 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 371 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 372 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 373 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 374 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 375 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 376 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 377 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 378 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 379 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 380 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 381 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 382 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 383 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 384 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 385 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 386 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 387 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 388 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 389 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 390 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1
# Ejemplo 391 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 392 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 393 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 394 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 395 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 2
# Ejemplo 396 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 397 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 398 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
#
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 399 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 0
# Ejemplo 400 de 400
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [2] Doble techo , [0] Sin patrón, [3] Descartar ejemplo
# 1

# %%
doble_suelo_techo_sin_patron_labels = pd.Series(etiquetas, index=ibex.index[idfechas.astype(np.int)])

# %% [markdown]
# Descartamos las etiquetas descartadas

# %%
doble_suelo_techo_sin_patron_labels = doble_suelo_techo_sin_patron_labels[doble_suelo_techo_sin_patron_labels!=3]

# %%
doble_suelo_techo_sin_patron_labels
# Out:
# 2012-12-06    0.0
# 2010-04-14    1.0
# 2013-07-09    0.0
# 2015-11-03    0.0
# 2013-01-29    1.0
#              ...
# 2009-11-09    2.0
# 2006-08-04    0.0
# 2011-12-29    0.0
# 2016-05-10    0.0
# 2002-02-01    1.0
# Length: 232, dtype: float64

# %%
doble_suelo_techo_sin_patron_labels.value_counts()
# Out:
# 0.0    160
# 1.0     39
# 2.0     33
# dtype: int64

# %% [markdown]
# Guardamos el fichero en CSV para su posterior procesamiento

# %%
doble_suelo_techo_sin_patron_labels.to_csv('ejemplos_doble_suelo_techo_sin_patron.csv')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.
